# %%
import pandas as pd

# %%
url = "https://media.githubusercontent.com/media/manoelgadi/CryptoGDelt2022/master/CryptoGDelt2022.csv"

# %%
url2 = "https://raw.githubusercontent.com/federico1802/TFN/main/BTC-Daily.csv"

# %%
crypto = pd.read_csv(url)

# %%
crypto.head(8)
# Out:
#    id                                                url  \
# 0   0  https://www.channel3000.com/photos-ripples-in-...
# 1   1  https://www.telegraph.co.uk/football/2021/03/3...
# 2   2  https://www.kvor.com/news/wall-st-dips-with-te...
# 3   3  https://techcrunch.com/2021/03/30/daily-crunch...
# 4   4  https://www.kcra.com/article/chipotle-is-givin...
# 5   5  https://www.bangkokpost.com/business/2092255/s...
# 6   6  https://www.kmbc.com/article/sevendays-campaig...
# 7   7  https://www.channelnewsasia.com/news/commentar...
#
#                                           url_mobile  \
# 0                                                NaN
# 1  https://www.telegraph.co.uk/football/2021/03/3...
# 2                                                NaN
# 3  https://techcrunch.com/2021/03/30/daily-crunch...
# 4  https://www.kcra.com/amp/article/chipotle-is-g...
# 5                                                NaN
# 6  https://www.kmbc.com/amp/article/sevendays-cam...
# ...

# %%
crypto.describe
# Out:
# <bound method NDFrame.describe of             id                                                url  \
# 0            0  https://www.channel3000.com/photos-ripples-in-...
# 1            1  https://www.telegraph.co.uk/football/2021/03/3...
# 2            2  https://www.kvor.com/news/wall-st-dips-with-te...
# 3            3  https://techcrunch.com/2021/03/30/daily-crunch...
# 4            4  https://www.kcra.com/article/chipotle-is-givin...
# ...        ...                                                ...
# 243417  243417  https://thesaxon.org/musk-sells-4-billion-in-t...
# 243418  243418  https://www.jdsupra.com/legalnews/the-impact-o...
# 243419  243419  https://www.miragenews.com/best-and-worst-perf...
# 243420  243420  https://hudsonvalleycountry.com/black-moon-apr...
# 243421  243421  https://wtop.com/tech/2022/04/data-doctors-cry...
#
#                                                url_mobile  \
# 0                                                     NaN
# ...

# %%
crypto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243422 entries, 0 to 243421
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              243422 non-null  int64
#  1   url                             243422 non-null  object
#  2   url_mobile                      105526 non-null  object
#  3   title                           243422 non-null  object
#  4   seendate                        243422 non-null  object
#  5   socialimage                     156442 non-null  object
#  6   domain                          243422 non-null  object
#  7   language                        243422 non-null  object
#  8   sourcecountry                   237756 non-null  object
#  9   lemmetized_titles               243422 non-null  object
#  10  relevance_probability           243422 non-null  float64
#  11  relevance_class                 243422 non-null  float64
# ...

# %%
crypto.groupby(by = 'sourcecountry').count()
# Out:
#                        id   url  url_mobile  title  seendate  socialimage  \
# sourcecountry
# Afghanistan            21    21           7     21        21           16
# Antigua and Barbuda     2     2           0      2         2            2
# Argentina              33    33           6     33        33           10
# Armenia                77    77           2     77        77           53
# Australia            5883  5883        3219   5883      5883         4539
# ...                   ...   ...         ...    ...       ...          ...
# Venezuela              12    12           1     12        12            5
# Vietnam               128   128          72    128       128           92
# Virgin Islands          9     9           0      9         9            0
# Zambia                  9     9           1      9         9            3
# Zimbabwe              215   215         144    215       215          182
#
#                      domain  language  lemmetized_titles  \
# ...

# %%
paises=crypto.pivot_table(index = "sourcecountry", values = "id", aggfunc = "count")

# %%
paises.sort_values('id', ascending=False).head(20)
# Out:
#                           id
# sourcecountry
# United States         139461
# United Kingdom         20873
# India                  20340
# China                  10927
# Canada                  6789
# Australia               5883
# Qatar                   3448
# Nigeria                 3445
# South Africa            3219
# Germany                 2228
# United Arab Emirates    1657
# Pakistan                1622
# Japan                   1371
# Ireland                 1322
# Philippines             1280
# Israel                  1134
# New Zealand             1122
# Malaysia                 910
# South Korea              780
# Russia                   739

# %%
bit2022 = pd.read_csv(url2,  parse_dates = ["date"])

# %%
bit2022.head(20)
# Out:
#           unix       date   symbol      open      high       low     close  \
# 0   1646092800 2022-03-01  BTC/USD  43221.71  43626.49  43185.48  43185.48
# 1   1646006400 2022-02-28  BTC/USD  37717.10  44256.08  37468.99  43178.98
# 2   1645920000 2022-02-27  BTC/USD  39146.66  39886.92  37015.74  37712.68
# 3   1645833600 2022-02-26  BTC/USD  39242.64  40330.99  38600.00  39146.66
# 4   1645747200 2022-02-25  BTC/USD  38360.93  39727.97  38027.61  39231.64
# 5   1645660800 2022-02-24  BTC/USD  37253.26  39720.00  34324.05  38376.88
# 6   1645574400 2022-02-23  BTC/USD  38269.94  39303.24  37060.16  37274.18
# 7   1645488000 2022-02-22  BTC/USD  37036.98  38463.88  36368.99  38269.94
# 8   1645401600 2022-02-21  BTC/USD  38384.09  39494.11  36810.72  37076.60
# 9   1645315200 2022-02-20  BTC/USD  40108.62  40151.62  37974.18  38373.90
# 10  1645228800 2022-02-19  BTC/USD  40008.75  40471.27  39587.08  40109.02
# ...

# %%
bit2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unix        2651 non-null   int64
#  1   date        2651 non-null   datetime64[ns]
#  2   symbol      2651 non-null   object
#  3   open        2651 non-null   float64
#  4   high        2651 non-null   float64
#  5   low         2651 non-null   float64
#  6   close       2651 non-null   float64
#  7   Volume BTC  2651 non-null   float64
#  8   Volume USD  2651 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(1)
# memory usage: 186.5+ KB

# %%
bitcorr=bit2022[bit2022.date >"01/01/2021" ]

# %%
import seaborn as sns
sns.relplot(x = "date", y = "close", data = bitcorr, kind = "line", height=9, aspect=15/8);

# %%
crypto.sort_values('relevance_probability', ascending=False).head(10)
# Out:
#             id                                                url  \
# 156164  156164  https://forextv.com/bitcoin-news/bitcoin-the-p...
# 226312  226312  https://www.zerohedge.com/crypto/bitcoin-barbe...
# 29472    29472  https://www.fool.com/investing/2021/05/20/cryp...
# 126909  126909  https://economictimes.indiatimes.com/prime/mon...
# 171241  171241  https://www.fool.com/investing/2022/01/22/cryp...
# 115307  115307  https://www.businessinsider.com.au/bitcoin-pri...
# 144030  144030  https://www.smh.com.au/business/markets/bitcoi...
# 61485    61485  https://time.com/nextadvisor/investing/cryptoc...
# 95657    95657  https://leaderpost.com/globe-newswire/todos-me...
# 85623    85623  https://www.dailyfx.com/forex/market_alert/202...
#
#                                                url_mobile  \
# 156164  https://forextv.com/bitcoin-news/bitcoin-the-p...
# 226312                                                NaN
# 29472   https://www.fool.com/amp/investing/2021/05/20/...
# ...

# %%
crypto.sort_values('sentiment_negative_probability', ascending=False).head(5)
# Out:
#             id                                                url  \
# 128501  128501  https://www.ripplesnigeria.com/fcmb-ignores-co...
# 214144  214144  https://www.euronews.com/next/2022/03/22/misle...
# 141025  141025  https://cryptoslate.com/grayscale-writes-a-let...
# 105606  105606  https://www.bnnbloomberg.ca/bitcoin-miner-nort...
# 234850  234850  https://www.ndtv.com/india-news/not-a-tis-haza...
#
#                                                url_mobile  \
# 128501  https://www.ripplesnigeria.com/fcmb-ignores-co...
# 214144                                                NaN
# 141025  https://cryptoslate.com/grayscale-writes-a-let...
# 105606  https://www.bnnbloomberg.ca/bitcoin-miner-nort...
# 234850  https://www.ndtv.com/india-news/not-a-tis-haza...
#
#                                                     title          seendate  \
# 128501  fcmb ignores court ruling links bitcoin trade ...  20211112T141500Z
# ...

# %%
crypto.sort_values('sentiment_positive_probability', ascending=False).head(5)
# Out:
#             id                                                url  \
# 66002    66002  https://zeenews.india.com/technology/amazon-ma...
# 161529  161529  https://techstory.in/cryptocurrencies-could-so...
# 65982    65982  https://www.business-standard.com/article/comp...
# 133208  133208  https://www.coinspeaker.com/paypal-crypto-paym...
# 26963    26963  https://www.streetinsider.com/PRNewswire/Holbo...
#
#                                                url_mobile  \
# 66002   https://zeenews.india.com/technology/amazon-ma...
# 161529                                                NaN
# 65982   https://wap.business-standard.com/article-amp/...
# 133208  https://www.coinspeaker.com/paypal-crypto-paym...
# 26963                                                 NaN
#
#                                                     title          seendate  \
# 66002   amazon may soon allow digital currency like bi...  20210725T090000Z
# ...

# %%
crypto.sort_values('strength_probability', ascending=False).head(10)
# Out:
#             id                                                url url_mobile  \
# 209936  209936  https://www.valdostadailytimes.com/news/nation...        NaN
# 205662  205662  https://www.chinanationalnews.com/news/2723828...        NaN
# 217659  217659  https://www.sheltonherald.com/entertainment/ar...        NaN
# 220517  220517  https://chicago.suntimes.com/2022/3/29/2299674...        NaN
# 216022  216022  https://www.newjerseytelegraph.com/news/272418...        NaN
# 209940  209940  https://infotel.ca/newsitem/us-theater-thornto...        NaN
# 207506  207506  https://www.thedailynewsonline.com/online_feat...        NaN
# 205611  205611  https://www.sheltonherald.com/news/article/Cas...        NaN
# 205666  205666  https://english.aawsat.com/home/article/352761...        NaN
# 205580  205580  https://www.fox5ny.com/news/cashless-and-fligh...        NaN
#
#                                                     title          seendate  \
# ...
